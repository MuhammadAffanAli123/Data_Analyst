# %% [markdown]
# # UNI Variable Measurment

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from matplotlib import style
style.use('seaborn-poster')

# %%
# csv = pd.read_csv('C:\\Users\\HP\\Downloads\\Histograms.csv')
csv= pd.read_csv('C:/Users/HP/Downloads/Histograms.csv')

# %%
# All coulmn MEANs

csv.mean()
# Out:
# A              50.632133
# B              65.544513
# C              50.851334
# D              50.211539
# Left Skew      21.019000
# Multimodal     49.539365
# IQ20           60.223886
# IQ100         102.925179
# dtype: float64

# %%
# Specific Colum Men
# mean of Coloumn 'B'

csv['B'].mean()
# Out:
# 65.54451334569998

# %% [markdown]
# I have Calculated mean Values of All column and finded Some Results
# mean of Col A              50.632133
# mean of Col B              65.544513
# mean of Col C              50.851334
# mean of Col D              50.211539
# mean of Col Left Skew      21.019000
# mean of Col Multimodal     49.539365
# mean of Col IQ20           60.223886
# mean of Col IQ100         102.925179
# mean of Col dtype: float64
#
# and we Can find mean of Specific Colum using specific name
# example:
# csv['B'].mean()
# mean of col B is 65.54451334569998

# %%
csv['B'].median()
# Out:
# 65.89879689

# %%
csv['Left Skew'].mode()
# Out:
# 0    23.0
# dtype: float64

# %%
csv['Left Skew'].median()
# Out:
# 21.5

# %%
csv['Left Skew'].mean()
# Out:
# 21.019000000000002

# %%
csv['C'].median()
# Out:
# 51.654882435

# %%
csv['A'].mean()
# Out:
# 50.63213316940001

# %%
csv.mean()
# Out:
# A              50.632133
# B              65.544513
# C              50.851334
# D              50.211539
# Left Skew      21.019000
# Multimodal     49.539365
# IQ20           60.223886
# IQ100         102.925179
# dtype: float64

# %%
csv.mean().hist()
# Out:
# <AxesSubplot:>

# %%
csv.median()
# Out:
# A              50.673711
# B              65.898797
# C              51.654882
# D              49.726685
# Left Skew      21.500000
# Multimodal     49.580639
# IQ20           51.099476
# IQ100         101.426575
# dtype: float64

# %%
csv.median().hist()
# Out:
# <AxesSubplot:>

# %%
csv.boxplot()
# Out:
# <AxesSubplot:>

# %%
a=csv.median()

# %%
a
# Out:
# A              50.673711
# B              65.898797
# C              51.654882
# D              49.726685
# Left Skew      21.500000
# Multimodal     49.580639
# IQ20           51.099476
# IQ100         101.426575
# dtype: float64
